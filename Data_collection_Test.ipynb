# %% [markdown]
# ### ***Cultural Health Moments:***
# A Search Analysis During Times of Heightened Awareness To Identify Potential Interception Points With Digital Health Consumers.

# %% [markdown]
# For the data collection in this project we are going to use Google Trend pecifically PyTrends. Google Trends => is a website by Google that analyzes the popularity of top search queries in Google Search across various regions and languages. The website uses graphs to compare the search volume of different queries over time. PyTrends inturn is a Python library/module/API that Allows simple interface for automating downloading of reports from Google Trends <br>

# %%
#importing the needed libraries, we will use the pandas dataframe to store the data from Google Trends 
import pytrends
import time
import pandas as pd
#we will have to import TrendReq from PyTrends to request data from Google Trends 
from pytrends.request import TrendReq

# %%
data = pd.read_csv('Data.txt')

# %%
data
# Out:
#              Name_of_HPP          Chronic_Condition Important_Date_1  \
# 0           Selena Gomez                      Lupus              NaN
# 1            Nick Cannon                      Lupus              NaN
# 2          Charlie Sheen                        HIV              NaN
# 3              Tom Hanks                   Diabetes              NaN
# 4          Jack Osbourne         Multiple Sclerosis              NaN
# 5             Nick Jonas                   Diabetes              NaN
# 6            Ben Stiller            Prostate Cancer       06/13/2014
# 7         Michael J. Fox        Parkinson's Disease              NaN
# 8   Elisabeth Hasselbeck             Celiac Disease              NaN
# 9        Montel Williams         Multiple Sclerosis              NaN
# 10         Bret Michaels              Heart Disease              NaN
# 11      Jillian Michaels  Polycystic Ovary Syndrome              NaN
# 12           Selma Blair         Multiple Sclerosis              NaN
# ...

# %%
data.to_csv('Data.csv')

# %%
#hl is the host language, 
#tz is the time zone and 
# retries is the number of retries total/connections/read all represented by one scalar
trends = TrendReq(hl = 'en-US', tz = 0, retries=10)
