# %% [markdown]
# ### ***Cultural Health Moments:***
# A Search Analysis During Times of Heightened Awareness To Identify Potential Interception Points With Digital Health Consumers.

# %% [markdown]
# ### ***Project Contributors:***
# > Sirui Yang
#
# > Kuzi Rusere
#
# > Ye An
#
# > Umair Shaikh

# %% [markdown]
# * ***Vision:*** Understanding how cultural health moments impact health consumers’ digital search behavior may provide insight into potential interception points relating to disease-state awareness, education, symptoms, diagnosis, and/or treatment.
# <br>
# <br>
# * ***Issue:*** During high-profile health moments (ex. – the cancer-related deaths of Chadwick Boseman and Eddie Van Halen, or the cancer diagnosis of Jimmy Carter or Rush Limbaugh) digital health consumers’ initial search queries are typically surface-level search (ex. – scandal, wealth, career highlights, spouse, etc.), but that search behavior shifts to awareness, signs, symptoms, and introspection over time. Understanding that time horizon – when the shift occurs and what common topical trends exist – may provide opportunities to engage by leveraging naturally occurring awareness and search.
# <br>
# <br>
# * ***Method:*** Examination of publicly available search data as related to high-profile disease state diagnosis and/or deaths. <br>
# <br>
# For the data collection in this project we are going to use Google Trend specifically PyTrends. Google Trends => is a website by Google that analyzes the popularity of top search queries in Google Search across various regions and languages. The website uses graphs to compare the search volume of different queries over time. PyTrends inturn is a Python library/module/API that Allows simple interface for automating downloading of reports from Google Trends <br>
# <br>
# The data/reports from Google Trends are given as relative popularity and not the actual search volume. <br> <br>
# From [Google Trends]("https://support.google.com/trends/answer/4365533?hl=en") =>
# "*Google Trends normalizes search data to make comparisons between terms easier. Search results are normalized to the time and location of a query by the following process:*"
#
# > 1. Each data point is divided by the total searches of the geography and time range it represents to compare relative popularity. Otherwise, places with the most search volume would always be ranked highest.
#
# > 2. The resulting numbers are then scaled on a range of 0 to 100 based on a topic’s proportion to all searches on all topics.
#
# > 3. Different regions that show the same search interest for a term don't always have the same total search volumes.
#
# * ***Potential Output:*** Present a use case identifying the window of heightened awareness and interest among health consumers caused by cultural health moments for use within strategic campaign development for advocacy groups (ex. – Komen, American Cancer Society), payers (Aetna, Blue Cross), and/or healthcare companies.

# %%
#importing the needed libraries, we will use the pandas dataframe to store the data from Google Trends 
import pytrends
import time
import pandas as pd
import datetime
import seaborn as sns
from ipywidgets import widgets, Layout
from IPython import display
from IPython.core.display import display, HTML
#we will have to import TrendReq from PyTrends to request data from Google Trends 
from pytrends.request import TrendReq

# %% [markdown]
# We have gathered a list of high-profile people that have been diagnosed with chronic diseases or have died from chronic diseases. The list has the name of the high-profile person and at least one important date. The important date is going to be either the date that they got diagnosed, the date that they announced that they had the chronic disease, or the date that they passed away from the chronic disease. The names and chronic disease are going to be used as keywords in Google Trends and the important dates will be used as the time interval.
# <br>
# <br>
# The list was saved into a CSV file called Cultural_Health_Moments.csv  and we will load that into a pandas dataframe.

# %%
#loading the list into a pandas dataframe
data = pd.read_csv('Cultural_Health Moments_Data.csv')

# %% [markdown]
# We're going to convert the important dates columns into pandas datetime

# %%
data['Important_Date_1'] =  pd.to_datetime(data['Important_Date_1'])
data['Important_Date_2'] =  pd.to_datetime(data['Important_Date_2'])

# %%
data
# Out:
#             Name_of_HPP     Chronic_Condition Important_Date_1  \
# 0          Selena Gomez                 Lupus       2017-09-14
# 1           Lena Dunham         Endometriosis       2018-02-14
# 2           Nick Cannon                 Lupus       2012-01-04
# 3         Charlie Sheen                   HIV       2015-11-17
# 4             Tom Hanks              Diabetes       2013-10-07
# 5         Jack Osbourne    Multiple Sclerosis       2012-06-18
# 6            Nick Jonas              Diabetes       2007-03-15
# 7           Ben Stiller       Prostate Cancer       2014-06-13
# 8             Lady Gaga          Fibromyalgia       2017-09-12
# 9           Alex Trebek     Pancreatic Cancer       2019-03-01
# 10     Chadwick Boseman          Colon Cancer       2020-08-28
# 11           Steve Jobs     Pancreatic Cancer       2004-08-01
# 12           Paul Allen  Non-Hodgkin Lymphoma       2009-10-01
# 13          John McCain          Glioblastoma       2015-06-16
# 14  Ruth Bader Ginsburg     Pancreatic Cancer       2009-02-05
# 15            John Hurt     Pancreatic Cancer       2015-06-16
# 16    Luciano Pavarotti     Pancreatic Cancer       2006-07-01
# 17         Sharon Jones     Pancreatic Cancer       2013-06-03
# 18         Alan Rickman     Pancreatic Cancer       2015-08-01
# 19       Gina Rodriguez   Hashimoto's disease       2014-10-15
# 20     Carrie Ann Inaba     Sjogren's disease       2021-04-26
# 21      Brittany Murphy             Pneumonia       2009-12-20
#
#    Important_Date_2
# 0               NaT
# 1               NaT
# 2        2016-04-14
# 3               NaT
# 4               NaT
# 5               NaT
# 6        2019-11-01
# 7        2016-10-04
# 8               NaT
# 9        2020-11-08
# 10              NaT
# 11       2011-10-05
# 12       2018-10-15
# 13       2018-08-24
# 14       2020-09-18
# 15       2017-01-25
# 16       2007-09-06
# 17       2016-11-18
# 18       2016-01-14
# 19              NaT
# 20              NaT
# 21              NaT

# %%
#hl is the host language, 
#tz is the time zone and 
# retries is the number of retries total/connections/read all represented by one scalar
pytrend = TrendReq(hl = 'en-US', tz = 0, retries=10)

# %% [markdown]
# We are going to first use the 'pytrends.suggestion' function which returns a list of additional suggested keywords that can be used to refine a trend search. The “mid” column in the resulting dataframe contains those exact keywords we’d like to search. <br>
#
# We will first do for the Name of High Profile Person column and the Chronic_Condition column saving these in seperate dataframes.

# %%
KEYWORDS= list(data.Name_of_HPP)
KEYWORDS_CODES=[pytrend.suggestions(keyword=i)[0] for i in KEYWORDS] 
df_HPP= pd.DataFrame(KEYWORDS_CODES)
df_HPP
# Out:
#            mid                         title  \
# 0    /m/0gs6vr                  Selena Gomez
# 1   /m/0b3w054                   Lena Dunham
# 2    /m/01d1st                   Nick Cannon
# 3    /m/01pllx                 Charlie Sheen
# 4     /m/0bxtg                     Tom Hanks
# 5    /m/02348n                 Jack Osbourne
# 6   /m/04f7c55                    Nick Jonas
# 7     /m/0mdqp                   Ben Stiller
# 8   /m/0478__m                     Lady Gaga
# 9    /m/01tbdb                   Alex Trebek
# 10  /m/0bm96gr              Chadwick Boseman
# 11    /m/06y3r                    Steve Jobs
# 12    /m/0pmw9                  Paul Shaffer
# 13    /m/0bymv                   John McCain
# 14   /m/0199pk           Ruth Bader Ginsburg
# 15   /m/015wnl                     John Hurt
# 16   /m/01h5j3             Luciano Pavarotti
# 17  /m/01n0q6h  Sharon Jones & the Dap-Kings
# 18    /m/09y20                  Alan Rickman
# 19  /m/02x4bn6                Gina Rodriguez
# 20   /m/073plk              Carrie Ann Inaba
# 21   /m/0168dy               Brittany Murphy
#
#                                                  type
# 0                                     American singer
# 1                                    American actress
# 2                                   American comedian
# 3                                      American actor
# 4                                      American actor
# 5                                   Media personality
# 6                          American singer-songwriter
# 7                                      American actor
# 8                          American singer-songwriter
# 9                    Canadian-American game show host
# 10                                     American actor
# 11                          American business magnate
# 12                                    Canadian singer
# 13                       Former United States Senator
# 14  Former Associate Justice of the Supreme Court ...
# 15                                              Actor
# 16                            Italian music performer
# 17                                               Band
# 18                                      English actor
# 19                               Pornographic actress
# 20                            American TV personality
# 21                                   American actress

# %%
KEYWORDS= list(data.Chronic_Condition)
KEYWORDS_CODES=[pytrend.suggestions(keyword=i)[0] for i in KEYWORDS] 
df_CC= pd.DataFrame(KEYWORDS_CODES)
df_CC
# Out:
#              mid                                       title  \
# 0       /m/04nz3                Systemic lupus erythematosus
# 1       /m/0d_9n                               Endometriosis
# 2       /m/04nz3                Systemic lupus erythematosus
# 3     /m/05dbslt                                         HIV
# 4       /m/0c58k                                    Diabetes
# 5       /m/0dcqh                          Multiple sclerosis
# 6       /m/0c58k                                    Diabetes
# 7       /m/0m32h                             Prostate cancer
# 8      /m/01v3ks                                Fibromyalgia
# 9      /m/01_qc_                           Pancreatic cancer
# 10    /m/04km8b1                           Colorectal cancer
# 11     /m/01_qc_                           Pancreatic cancer
# 12      /m/0jdj1                        Non-Hodgkin lymphoma
# 13     /m/03_5ld                                Glioblastoma
# 14     /m/01_qc_                           Pancreatic cancer
# 15     /m/01_qc_                           Pancreatic cancer
# 16     /m/01_qc_                           Pancreatic cancer
# 17     /m/01_qc_                           Pancreatic cancer
# 18     /m/01_qc_                           Pancreatic cancer
# 19     /m/030mph                     Hashimoto's thyroiditis
# 20  /g/12bm5l70j  Family Practice Guidelines: Second Edition
# 21      /m/0dq9p                                   Pneumonia
#
#                  type
# 0             Disease
# 1             Disease
# 2             Disease
# 3               Virus
# 4            Disorder
# 5             Disease
# 6            Disorder
# 7             Disease
# 8   Medical condition
# 9               Topic
# 10   Genetic disorder
# 11              Topic
# 12            Disease
# 13   Genetic disorder
# 14              Topic
# 15              Topic
# 16              Topic
# 17              Topic
# 18              Topic
# 19            Disease
# 20              Topic
# 21            Disease

# %% [markdown]
# We are going to create a supporting fuction to create the date interval

# %%
def create_date_interval(date):
    """
    This fuction creates the date interval needed for as one of the parameters for the pytrend.build_payload fuction
    The function takes in the important date and returns a string of the date interval +/- 30 days
    """
    start_date = date - datetime.timedelta(days= 30)
    end_date = date + datetime.timedelta(days=30)

    x = (str(start_date)).split()[0]
    y = (str(end_date)).split()[0]
    
    date_interval = f"{x} {y}"

    return date_interval

# %% [markdown]
# We will create a function that will output a dataframe of the Google Trends search data results

# %%
def dataframe_of_trends(num):
    """
    This fuction outputs a dataframe of the trends data/results from google trends
    It inputs the index from the 'data' dataframe which is housing the Cultural health moments High Profile people and chronic condition data 
    it will also output dictionary of the 'related, top and rising queries' which we will need for later.  
    """
    #setting up the parameters for the payload
    KEYWORDS=[df_HPP.mid[num], df_CC.mid[num]]
    DATE_INTERVAL= create_date_interval(data.Important_Date_1[num])
    COUNTRY="US" 
    CATEGORY = 0 
    SEARCH_TYPE=''
    #######################
    #the below is building the payload using the above parameters
    pytrend.build_payload( kw_list= KEYWORDS, timeframe = DATE_INTERVAL, geo = COUNTRY, cat=CATEGORY,gprop=SEARCH_TYPE) 
    df = pytrend.interest_over_time() #we will  assign the interest_overtime/trends dataframe to df
    #now we will rename the column name from the pytrends suggested mid value to the actual name of the high profile person and chronic condition 
    df = df.rename(columns={KEYWORDS[0]: data.Name_of_HPP[num], KEYWORDS[1]: data.Chronic_Condition[num]})
    df.drop('isPartial', axis=1, inplace=True)

    #now we will grab the dictionary of the related, top and rising queries and rename the keys
    related_queries = pytrend.related_queries()
    related_queries[data.Name_of_HPP[num]] = related_queries.pop(KEYWORDS[0])
    related_queries[data.Chronic_Condition[num]] = related_queries.pop(KEYWORDS[1])
    #now we will seperate the dictionary into HPP_related_queries and the CC_related_queries 
    HPP_related_queries = related_queries[data.Name_of_HPP[num]]
    CC_related_queries = related_queries[data.Chronic_Condition[num]]

    return df, HPP_related_queries, CC_related_queries, DATE_INTERVAL

# %%
df, HPP_related_queries, CC_related_queries, date_interval = dataframe_of_trends(0)

# %%
df
# Out:
#             Selena Gomez  Lupus
# date
# 2017-08-15            18     11
# 2017-08-16            15     11
# 2017-08-17            16     11
# 2017-08-18            15      9
# 2017-08-19            19      9
# ...                  ...    ...
# 2017-10-10            11     13
# 2017-10-11            12     14
# 2017-10-12            14     14
# 2017-10-13            13     12
# 2017-10-14            12     11
#
# [61 rows x 2 columns]

# %% [markdown]
# We will create a function that plots out the trends between the high profile person and the chronic condition within the date interval

# %%
def show_the_trend(df,date_interval):
    """   
    This fuction plotout the trend of the High Profile Person and the Chronic Condition within the date interval
    """
    sns.set(rc={'figure.figsize':(15,10)})
    sns.lineplot(data=df).set_title(f"Search Plot of {df.columns[0]} and {df.columns[1]} in the date interval {date_interval}")

# %%
show_the_trend(df,date_interval)

# %% [markdown]
# We created a function that will separate the top related queries and the rising related queries

# %%
def get_top_and_rising(related_queries_dict):
    """  
    This fuction returns the top and rising related queries 
    """
    # for rising related queries
    related_queries_rising = related_queries_dict.get('rising')
    # for top related queries
    related_queries_top = related_queries_dict.get('top')

    return related_queries_rising, related_queries_top

# %% [markdown]
# We found a function on [StackOverflow](https://stackoverflow.com/questions/38783027/jupyter-notebook-display-two-pandas-tables-side-by-side) that allows us to display data frames of the top related queries and rising related queries side by side, so we're going to be utilizing that to show these trends side by side fist for the High Profile Person and then the Chronic condition.

# %%
def display_side_by_side(dfs:list, captions:list):
    """Display tables side by side to save vertical space
    Input:
        dfs: list of pandas.DataFrame
        captions: list of table captions
    """
    output = ""
    combined = dict(zip(captions, dfs))
    for caption, df in combined.items():
        output += df.style.set_table_attributes("style='display:inline'").set_caption(caption)._repr_html_()
        output += "\xa0\xa0\xa0"
    display(HTML(output))

# %%
related_queries_rising, related_queries_top = get_top_and_rising(HPP_related_queries)
df1 = related_queries_top
df2 = related_queries_rising
display_side_by_side([df1, df2], ['caption1', 'caption2'])
# Out:
# <style type="text/css">
# </style>
# <table id="T_e04eb_" style='display:inline'>
#   <caption>caption1</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >query</th>
#       <th class="col_heading level0 col1" >value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e04eb_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e04eb_row0_col0" class="data row0 col0" >selena</td>
#       <td id="T_e04eb_row0_col1" class="data row0 col1" >100</td>
#     </tr>
#     <tr>
#       <th id="T_e04eb_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_e04eb_row1_col0" class="data row1 col0" >selena gomez</td>
#       <td id="T_e04eb_row1_col1" class="data row1 col1" >93</td>
#     </tr>
#     <tr>
#       <th id="T_e04eb_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_e04eb_row2_col0" class="data row2 col0" >justin bieber</td>
#       <td id="T_e04eb_row2_col1" class="data row2 col1" >7</td>
#     </tr>
#     <tr>
#       <th id="T_e04eb_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_e04eb_row3_col0" class="data row3 col0" >justin bieber selena gomez</td>
#       <td id="T_e04eb_row3_col1" class="data row3 col1" >6</td>
#     </tr>
#     <tr>
#       <th id="T_e04eb_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_e04eb_row4_col0" class="data row4 col0" >selena gomez instagram</td>
#       <td id="T_e04eb_row4_col1" class="data row4 col1" >6</td>
#     </tr>
#     <tr>
#       <th id="T_e04eb_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_e04eb_row5_col0" class="data row5 col0" >selena weeknd</td>
#       <td id="T_e04eb_row5_col1" class="data row5 col1" >6</td>
#     </tr>
#     <tr>
#       <th id="T_e04eb_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_e04eb_row6_col0" class="data row6 col0" >the weeknd</td>
#       <td id="T_e04eb_row6_col1" class="data row6 col1" >6</td>
#     </tr>
#     <tr>
#       <th id="T_e04eb_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_e04eb_row7_col0" class="data row7 col0" >selena the weeknd</td>
#       <td id="T_e04eb_row7_col1" class="data row7 col1" >5</td>
#     </tr>
#     <tr>
#       <th id="T_e04eb_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_e04eb_row8_col0" class="data row8 col0" >selena gomez weeknd</td>
#       <td id="T_e04eb_row8_col1" class="data row8 col1" >5</td>
#     </tr>
#     <tr>
#       <th id="T_e04eb_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_e04eb_row9_col0" class="data row9 col0" >selena gomez kidney</td>
#       <td id="T_e04eb_row9_col1" class="data row9 col1" >5</td>
#     </tr>
#     <tr>
#       <th id="T_e04eb_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_e04eb_row10_col0" class="data row10 col0" >the weeknd selena gomez</td>
#       <td id="T_e04eb_row10_col1" class="data row10 col1" >5</td>
#     </tr>
#     <tr>
#       <th id="T_e04eb_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_e04eb_row11_col0" class="data row11 col0" >selena gomez 2017</td>
#       <td id="T_e04eb_row11_col1" class="data row11 col1" >4</td>
#     </tr>
#     <tr>
#       <th id="T_e04eb_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_e04eb_row12_col0" class="data row12 col0" >lupus</td>
#       <td id="T_e04eb_row12_col1" class="data row12 col1" >4</td>
#     </tr>
#     <tr>
#       <th id="T_e04eb_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_e04eb_row13_col0" class="data row13 col0" >the weeknd and selena</td>
#       <td id="T_e04eb_row13_col1" class="data row13 col1" >4</td>
#     </tr>
#     <tr>
#       <th id="T_e04eb_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_e04eb_row14_col0" class="data row14 col0" >taylor swift</td>
#       <td id="T_e04eb_row14_col1" class="data row14 col1" >3</td>
#     </tr>
#     <tr>
#       <th id="T_e04eb_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_e04eb_row15_col0" class="data row15 col0" >selena gomez lupus</td>
#       <td id="T_e04eb_row15_col1" class="data row15 col1" >3</td>
#     </tr>
#     <tr>
#       <th id="T_e04eb_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_e04eb_row16_col0" class="data row16 col0" >selena gomez transplant</td>
#       <td id="T_e04eb_row16_col1" class="data row16 col1" >3</td>
#     </tr>
#     <tr>
#       <th id="T_e04eb_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_e04eb_row17_col0" class="data row17 col0" >selena gomez hacked</td>
#       <td id="T_e04eb_row17_col1" class="data row17 col1" >3</td>
#     </tr>
#     <tr>
#       <th id="T_e04eb_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_e04eb_row18_col0" class="data row18 col0" >selena gomez age</td>
#       <td id="T_e04eb_row18_col1" class="data row18 col1" >3</td>
#     </tr>
#     <tr>
#       <th id="T_e04eb_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_e04eb_row19_col0" class="data row19 col0" >the weekend</td>
#       <td id="T_e04eb_row19_col1" class="data row19 col1" >3</td>
#     </tr>
#     <tr>
#       <th id="T_e04eb_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_e04eb_row20_col0" class="data row20 col0" >francia raisa</td>
#       <td id="T_e04eb_row20_col1" class="data row20 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_e04eb_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_e04eb_row21_col0" class="data row21 col0" >demi lovato</td>
#       <td id="T_e04eb_row21_col1" class="data row21 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_e04eb_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_e04eb_row22_col0" class="data row22 col0" >ariana grande</td>
#       <td id="T_e04eb_row22_col1" class="data row22 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_e04eb_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_e04eb_row23_col0" class="data row23 col0" >francia raisa selena gomez</td>
#       <td id="T_e04eb_row23_col1" class="data row23 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_e04eb_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_e04eb_row24_col0" class="data row24 col0" >selena gomez net worth</td>
#       <td id="T_e04eb_row24_col1" class="data row24 col1" >2</td>
#     </tr>
#   </tbody>
# </table>
#    <style type="text/css">
# </style>
# <table id="T_fa147_" style='display:inline'>
#   <caption>caption2</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >query</th>
#       <th class="col_heading level0 col1" >value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fa147_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_fa147_row0_col0" class="data row0 col0" >selena gomez kidney</td>
#       <td id="T_fa147_row0_col1" class="data row0 col1" >355150</td>
#     </tr>
#     <tr>
#       <th id="T_fa147_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_fa147_row1_col0" class="data row1 col0" >selena gomez transplant</td>
#       <td id="T_fa147_row1_col1" class="data row1 col1" >232750</td>
#     </tr>
#     <tr>
#       <th id="T_fa147_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_fa147_row2_col0" class="data row2 col0" >francia raisa</td>
#       <td id="T_fa147_row2_col1" class="data row2 col1" >170650</td>
#     </tr>
#     <tr>
#       <th id="T_fa147_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_fa147_row3_col0" class="data row3 col0" >selena gomez kidney transplant</td>
#       <td id="T_fa147_row3_col1" class="data row3 col1" >139000</td>
#     </tr>
#     <tr>
#       <th id="T_fa147_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_fa147_row4_col0" class="data row4 col0" >selena gomez hack</td>
#       <td id="T_fa147_row4_col1" class="data row4 col1" >37550</td>
#     </tr>
#     <tr>
#       <th id="T_fa147_level0_row5" class="row_heading level0 row5" >5</th>

# %%
related_queries_rising, related_queries_top = get_top_and_rising(CC_related_queries)
df1 = related_queries_top
df2 = related_queries_rising
display_side_by_side([df1, df2], ['caption1', 'caption2'])
# Out:
# <style type="text/css">
# </style>
# <table id="T_a993d_" style='display:inline'>
#   <caption>caption1</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >query</th>
#       <th class="col_heading level0 col1" >value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a993d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a993d_row0_col0" class="data row0 col0" >lupus</td>
#       <td id="T_a993d_row0_col1" class="data row0 col1" >100</td>
#     </tr>
#     <tr>
#       <th id="T_a993d_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_a993d_row1_col0" class="data row1 col0" >lupus symptoms</td>
#       <td id="T_a993d_row1_col1" class="data row1 col1" >20</td>
#     </tr>
#     <tr>
#       <th id="T_a993d_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_a993d_row2_col0" class="data row2 col0" >what is lupus</td>
#       <td id="T_a993d_row2_col1" class="data row2 col1" >9</td>
#     </tr>
#     <tr>
#       <th id="T_a993d_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_a993d_row3_col0" class="data row3 col0" >sle</td>
#       <td id="T_a993d_row3_col1" class="data row3 col1" >8</td>
#     </tr>
#     <tr>
#       <th id="T_a993d_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_a993d_row4_col0" class="data row4 col0" >lupus disease</td>
#       <td id="T_a993d_row4_col1" class="data row4 col1" >5</td>
#     </tr>
#     <tr>
#       <th id="T_a993d_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_a993d_row5_col0" class="data row5 col0" >selena gomez</td>
#       <td id="T_a993d_row5_col1" class="data row5 col1" >5</td>
#     </tr>
#     <tr>
#       <th id="T_a993d_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_a993d_row6_col0" class="data row6 col0" >symptoms of lupus</td>
#       <td id="T_a993d_row6_col1" class="data row6 col1" >5</td>
#     </tr>
#     <tr>
#       <th id="T_a993d_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_a993d_row7_col0" class="data row7 col0" >selena gomez lupus</td>
#       <td id="T_a993d_row7_col1" class="data row7 col1" >4</td>
#     </tr>
#     <tr>
#       <th id="T_a993d_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_a993d_row8_col0" class="data row8 col0" >lupus rash</td>
#       <td id="T_a993d_row8_col1" class="data row8 col1" >4</td>
#     </tr>
#     <tr>
#       <th id="T_a993d_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_a993d_row9_col0" class="data row9 col0" >lupis</td>
#       <td id="T_a993d_row9_col1" class="data row9 col1" >3</td>
#     </tr>
#     <tr>
#       <th id="T_a993d_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_a993d_row10_col0" class="data row10 col0" >lupus kidney</td>
#       <td id="T_a993d_row10_col1" class="data row10 col1" >3</td>
#     </tr>
#     <tr>
#       <th id="T_a993d_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_a993d_row11_col0" class="data row11 col0" >lupus signs</td>
#       <td id="T_a993d_row11_col1" class="data row11 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_a993d_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_a993d_row12_col0" class="data row12 col0" >signs of lupus</td>
#       <td id="T_a993d_row12_col1" class="data row12 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_a993d_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_a993d_row13_col0" class="data row13 col0" >lupus treatment</td>
#       <td id="T_a993d_row13_col1" class="data row13 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_a993d_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_a993d_row14_col0" class="data row14 col0" >systemic lupus erythematosus</td>
#       <td id="T_a993d_row14_col1" class="data row14 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_a993d_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_a993d_row15_col0" class="data row15 col0" >lupus causes</td>
#       <td id="T_a993d_row15_col1" class="data row15 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_a993d_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_a993d_row16_col0" class="data row16 col0" >skin lupus</td>
#       <td id="T_a993d_row16_col1" class="data row16 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_a993d_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_a993d_row17_col0" class="data row17 col0" >what is lupus disease</td>
#       <td id="T_a993d_row17_col1" class="data row17 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_a993d_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_a993d_row18_col0" class="data row18 col0" >lupus walk</td>
#       <td id="T_a993d_row18_col1" class="data row18 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_a993d_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_a993d_row19_col0" class="data row19 col0" >lupus foundation</td>
#       <td id="T_a993d_row19_col1" class="data row19 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_a993d_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_a993d_row20_col0" class="data row20 col0" >fibromyalgia</td>
#       <td id="T_a993d_row20_col1" class="data row20 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_a993d_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_a993d_row21_col0" class="data row21 col0" >lupus kidney transplant</td>
#       <td id="T_a993d_row21_col1" class="data row21 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_a993d_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_a993d_row22_col0" class="data row22 col0" >lupus definition</td>
#       <td id="T_a993d_row22_col1" class="data row22 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_a993d_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_a993d_row23_col0" class="data row23 col0" >lupus butterfly rash</td>
#       <td id="T_a993d_row23_col1" class="data row23 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_a993d_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_a993d_row24_col0" class="data row24 col0" >rheumatoid arthritis</td>
#       <td id="T_a993d_row24_col1" class="data row24 col1" >1</td>
#     </tr>
#   </tbody>
# </table>
#    <style type="text/css">
# </style>
# <table id="T_d253b_" style='display:inline'>
#   <caption>caption2</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >query</th>
#       <th class="col_heading level0 col1" >value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d253b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d253b_row0_col0" class="data row0 col0" >lupus kidney transplant</td>
#       <td id="T_d253b_row0_col1" class="data row0 col1" >68350</td>
#     </tr>
#     <tr>
#       <th id="T_d253b_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_d253b_row1_col0" class="data row1 col0" >lady gaga lupus</td>
#       <td id="T_d253b_row1_col1" class="data row1 col1" >51000</td>
#     </tr>
#     <tr>
#       <th id="T_d253b_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_d253b_row2_col0" class="data row2 col0" >francia raisa</td>
#       <td id="T_d253b_row2_col1" class="data row2 col1" >30300</td>
#     </tr>
#     <tr>
#       <th id="T_d253b_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_d253b_row3_col0" class="data row3 col0" >selena gomez kidney</td>
#       <td id="T_d253b_row3_col1" class="data row3 col1" >12750</td>
#     </tr>
#     <tr>
#       <th id="T_d253b_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_d253b_row4_col0" class="data row4 col0" >k michelle lupus</td>
#       <td id="T_d253b_row4_col1" class="data row4 col1" >12350</td>
#     </tr>
#     <tr>
#       <th id="T_d253b_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_d253b_row5_col0" class="data row5 col0" >can lupus be fatal</td

# %%
len(df1)
# Out:
# 25
